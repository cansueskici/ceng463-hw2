# %%
# !pip install transformers datasets torch evaluate huggingface_hub
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 29.1 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, classification_report
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments, BertTokenizer, BertModel, AutoModelForCausalLM, pipeline
from datasets import Dataset
from google.colab import userdata
import torch
import numpy
from huggingface_hub import login
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
power_data = pd.read_csv("/content/power-lv-train.tsv", sep="\t")
dataset = Dataset.from_pandas(power_data)

# %%
login(userdata.get('h_token'))

# %%
tokenizer = AutoTokenizer.from_pretrained(
    "meta-llama/Llama-3.1-8B-Instruct",
    offload_folder="auto",
)
model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-3.1-8B-Instruct",
    offload_folder="auto",
    device_map="auto",
    torch_dtype=torch.float16
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]

# %%
def inference(batch, lang="text"):
    results = []
    for text in tqdm(batch[lang], desc=f"Classifying texts ({lang})"):
        prompt = (
           f"Classify the following political statement into one of two categories: 'opposition' or 'governing'. "
            f"Respond with only the category, and say 'the answer is 'opposition.' or 'the answer is 'governing.'."
            f"Statement: {text}\n\n"
            f"Answer:"
        )

        inputs = tokenizer(prompt, return_tensors="pt").to(device)

        with torch.no_grad():
            outputs = model.generate(**inputs, max_new_tokens=50, temperature=0.7, num_return_sequences=1)

        raw_prediction = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()

        prediction = raw_prediction.split("Answer:")[1].strip().lower()

        if "governing" in prediction.lower():
            results.append(0)
        else:
            results.append(1)

    return {"predictions": results}



en_predictions = []
batch_size = 10

for i in range(0, len(dataset), batch_size):
    batch = dataset[i : i + batch_size]
    predictions = inference(batch, "text_en")
    en_predictions.extend(predictions["predictions"])

lv_predictions = []
for i in range(0, len(dataset), batch_size):
    batch = dataset[i : i + batch_size]
    predictions = inference(batch)
    lv_predictions.extend(predictions["predictions"])
# Out:
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:03<00:34,  3.85s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:05<00:22,  2.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:07<00:16,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:09<00:13,  2.27s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:11<00:10,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:05,  1.48s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:04,  1.65s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:03,  1.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:01,  1.83s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.00s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:01<00:17,  1.99s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:03<00:16,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:05<00:14,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.04s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:18<00:00,  1.85s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.05s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:01<00:17,  1.99s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.01s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:19,  2.16s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.04s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.05s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:08<00:07,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:08<00:04,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:10<00:04,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:12<00:03,  1.58s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:14<00:01,  1.72s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:16<00:00,  1.70s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:08<00:06,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:10<00:06,  1.59s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:12<00:05,  1.80s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:14<00:03,  1.87s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:16<00:01,  1.92s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:14<00:03,  1.52s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:16<00:01,  1.68s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.07s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:03<00:11,  1.48s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:05<00:12,  1.78s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:07<00:11,  1.89s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:09<00:09,  1.95s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:11<00:07,  1.97s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:13<00:06,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:13<00:02,  1.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:15<00:01,  1.66s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:17<00:00,  1.79s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.05s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.06s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.07s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:08<00:07,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:10<00:06,  1.64s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:10<00:03,  1.21s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:12<00:02,  1.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:14<00:01,  1.65s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:16<00:00,  1.70s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:17,  2.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:04<00:08,  1.27s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:06<00:09,  1.61s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:08<00:08,  1.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:10<00:07,  1.85s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:12<00:05,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:14<00:03,  1.96s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:16<00:01,  1.98s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.08s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:04<00:08,  1.27s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:06<00:09,  1.56s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:08<00:08,  1.72s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:10<00:07,  1.83s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:12<00:05,  1.91s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:14<00:03,  1.94s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:16<00:01,  1.96s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:00<00:03,  2.96it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:02<00:10,  1.33s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:04<00:11,  1.64s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:06<00:10,  1.79s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:08<00:09,  1.87s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:10<00:07,  1.94s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:12<00:06,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:14<00:04,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:16<00:02,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:00<00:01,  7.12it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:02<00:10,  1.26s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:04<00:11,  1.61s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:06<00:10,  1.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:08<00:09,  1.86s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:10<00:07,  1.91s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:12<00:05,  1.97s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:14<00:04,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:16<00:02,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:18<00:00,  1.85s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:10<00:05,  1.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:12<00:04,  1.64s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:14<00:03,  1.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:16<00:01,  1.84s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en): 100%|██████████| 10/10 [00:18<00:00,  1.87s/it]
# Classifying texts (text_en):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  10%|█         | 1/10 [00:02<00:18,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  20%|██        | 2/10 [00:04<00:16,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  30%|███       | 3/10 [00:06<00:14,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  40%|████      | 4/10 [00:08<00:12,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  50%|█████     | 5/10 [00:10<00:10,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  60%|██████    | 6/10 [00:12<00:08,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  70%|███████   | 7/10 [00:14<00:06,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  80%|████████  | 8/10 [00:16<00:04,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text_en):  90%|█████████ | 9/10 [00:18<00:02,  2.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ...
# Classifying texts (text):  50%|█████     | 5/10 [00:10<00:10,  2.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:12<00:08,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:14<00:06,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:16<00:04,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:18<00:02,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:20<00:00,  2.08s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:20,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:17,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:06<00:15,  2.19s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:08<00:12,  2.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:10<00:10,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:12<00:08,  2.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:15<00:06,  2.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:17<00:04,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:19<00:02,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:21<00:00,  2.12s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:19,  2.20s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:17,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:06<00:14,  2.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:08<00:12,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:10<00:10,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:11<00:06,  1.67s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:11<00:03,  1.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:13<00:03,  1.51s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:16<00:01,  1.70s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:18<00:00,  1.81s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:18,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:16,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:06<00:14,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:08<00:12,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:10<00:10,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:12<00:08,  2.16s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:14<00:06,  2.15s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:16<00:04,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:18<00:02,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:21<00:00,  2.10s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:19,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:16,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:06<00:14,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:08<00:12,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:10<00:10,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:12<00:08,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:14<00:06,  2.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:16<00:04,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:18<00:02,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:20<00:00,  2.06s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:23,  2.65s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:18,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:06<00:15,  2.18s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:08<00:12,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:10<00:10,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:12<00:08,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:15<00:06,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:17<00:04,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:19<00:02,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:21<00:00,  2.11s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:19,  2.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:16,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:06<00:14,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:08<00:12,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:10<00:10,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:10<00:06,  1.51s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:13<00:05,  1.72s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:15<00:03,  1.87s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:17<00:01,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:19<00:00,  1.96s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:19,  2.15s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:16,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:04<00:09,  1.29s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:06<00:09,  1.61s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:08<00:08,  1.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:10<00:07,  1.87s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:12<00:05,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:14<00:03,  1.97s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:16<00:01,  1.99s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:18,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:17,  2.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:06<00:14,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:06<00:08,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:08<00:08,  1.63s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:10<00:07,  1.77s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:12<00:05,  1.88s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:13<00:02,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:15<00:01,  1.62s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:17<00:00,  1.74s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:19,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:16,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:06<00:14,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:08<00:13,  2.18s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:10<00:10,  2.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:12<00:08,  2.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:14<00:06,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:16<00:04,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:19<00:02,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:21<00:00,  2.10s/it]
# Classifying texts (text):   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  10%|█         | 1/10 [00:02<00:18,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  20%|██        | 2/10 [00:04<00:16,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  30%|███       | 3/10 [00:06<00:14,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  40%|████      | 4/10 [00:08<00:12,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  50%|█████     | 5/10 [00:10<00:10,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  60%|██████    | 6/10 [00:12<00:08,  2.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  70%|███████   | 7/10 [00:14<00:06,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  80%|████████  | 8/10 [00:16<00:04,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text):  90%|█████████ | 9/10 [00:18<00:02,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Classifying texts (text): 100%|██████████| 10/10 [00:20<00:00,  2.09s/it]

# %%
print("Classification Report for Latvian:")
print(classification_report(dataset["label"], lv_predictions))

print("Classification Report for English:")
print(classification_report(dataset["label"], en_predictions))
# Out:
# Classification Report for Latvian:
#               precision    recall  f1-score   support
#
#            0       0.75      0.27      0.39       944
#            1       0.35      0.82      0.49       466
#
#     accuracy                           0.45      1410
#    macro avg       0.55      0.54      0.44      1410
# weighted avg       0.62      0.45      0.43      1410
#
# Classification Report for English:
#               precision    recall  f1-score   support
#
#            0       0.72      0.57      0.64       944
#            1       0.39      0.56      0.46       466
#
#     accuracy                           0.57      1410
#    macro avg       0.56      0.57      0.55      1410
# weighted avg       0.61      0.57      0.58      1410
